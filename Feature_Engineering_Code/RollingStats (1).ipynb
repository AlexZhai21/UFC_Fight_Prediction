# %%
import pandas as pd

# %%
df = pd.read_csv("fight_results.csv")

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df
# Out:
#       Unnamed: 0       Date       Weight class Method  Round Winner  \
# 0              0 2025-07-26       Middleweight    DEC      5   Blue
# 1              1 2025-07-26       Bantamweight    DEC      3   Blue
# 2              2 2025-07-26       Middleweight    DEC      3   Blue
# 3              3 2025-07-26          Flyweight    DEC      3   Blue
# 4              4 2025-07-26  Light Heavyweight     KO      1   Blue
# ...          ...        ...                ...    ...    ...    ...
# 8271        8271 1994-03-11        Open Weight     KO      1   Blue
# 8272        8272 1994-03-11        Open Weight    SUB      1   Blue
# 8273        8273 1994-03-11        Open Weight     KO      1   Blue
# 8274        8274 1994-03-11        Open Weight    SUB      1   Blue
# 8275        8275 1994-03-11        Open Weight    SUB      1   Blue
#
#                    Blue                   Red  Blue_Kd_Landed  Red_Kd_Landed  \
# 0     Reinier de Ridder      Robert Whittaker             0.0            1.0
# 1              Petr Yan         Marcus McGhee             0.0            0.0
# 2       Shara Magomedov  Marc-Andre Barriault             0.0            0.0
# 3         Asu Almabayev            Jose Ochoa             0.0            0.0
# 4         Bogdan Guskov         Nikita Krylov             1.0            0.0
# ...                 ...                   ...             ...            ...
# 8271       Orlando Wiet      Robert Lucarelli             0.0            0.0
# 8272      Frank Hamaker       Thaddeus Luster             0.0            0.0
# 8273      Johnny Rhodes         David Levicki             0.0            0.0
# 8274      Patrick Smith            Ray Wizard             0.0            0.0
# 8275       Scott Morris        Sean Daugherty             0.0            0.0
#
#       Blue_Str_Landed  Red_Str_Landed  Blue_Sub_Landed  Red_Sub_Landed
# 0                67.0            66.0              0.0             0.0
# 1                81.0            64.0              0.0             0.0
# 2                93.0            39.0              0.0             0.0
# 3                22.0            26.0              2.0             2.0
# 4                23.0            16.0              0.0             0.0
# ...               ...             ...              ...             ...
# 8271              8.0             2.0              0.0             1.0
# 8272              2.0             0.0              3.0             0.0
# 8273             11.0             4.0              0.0             0.0
# 8274              1.0             1.0              1.0             0.0
# 8275              1.0             0.0              1.0             0.0
#
# [8276 rows x 14 columns]

# %%
blue_df = df[[
    "Date", "Blue", "Red", "Winner",
    "Blue_Kd_Landed", "Blue_Str_Landed", "Blue_Sub_Landed"
]].rename(columns={
    "Blue": "Fighter",
    "Red": "Opponent",
    "Blue_Kd_Landed": "KD",
    "Blue_Str_Landed": "STR",
    "Blue_Sub_Landed": "SUB"
})
blue_df["Was_Blue"] = True
blue_df["Is_Winner"] = True

# %%
blue_df.head()
# Out:
#         Date            Fighter              Opponent Winner   KD   STR  SUB  \
# 0 2025-07-26  Reinier de Ridder      Robert Whittaker   Blue  0.0  67.0  0.0
# 1 2025-07-26           Petr Yan         Marcus McGhee   Blue  0.0  81.0  0.0
# 2 2025-07-26    Shara Magomedov  Marc-Andre Barriault   Blue  0.0  93.0  0.0
# 3 2025-07-26      Asu Almabayev            Jose Ochoa   Blue  0.0  22.0  2.0
# 4 2025-07-26      Bogdan Guskov         Nikita Krylov   Blue  1.0  23.0  0.0
#
#    Was_Blue  Is_Winner
# 0      True       True
# 1      True       True
# 2      True       True
# 3      True       True
# 4      True       True

# %%
red_df = df[[
    "Date", "Red", "Blue", "Winner",
    "Red_Kd_Landed", "Red_Str_Landed", "Red_Sub_Landed"
]].rename(columns={
    "Blue": "Opponent",
    "Red": "Fighter",
    
    "Red_Kd_Landed": "KD",
    "Red_Str_Landed": "STR",
    "Red_Sub_Landed": "SUB"
})
red_df["Was_Blue"] = False
red_df["Is_Winner"] = False

# %%
red_df.head()
# Out:
#         Date               Fighter           Opponent Winner   KD   STR  SUB  \
# 0 2025-07-26      Robert Whittaker  Reinier de Ridder   Blue  1.0  66.0  0.0
# 1 2025-07-26         Marcus McGhee           Petr Yan   Blue  0.0  64.0  0.0
# 2 2025-07-26  Marc-Andre Barriault    Shara Magomedov   Blue  0.0  39.0  0.0
# 3 2025-07-26            Jose Ochoa      Asu Almabayev   Blue  0.0  26.0  2.0
# 4 2025-07-26         Nikita Krylov      Bogdan Guskov   Blue  0.0  16.0  0.0
#
#    Was_Blue  Is_Winner
# 0     False      False
# 1     False      False
# 2     False      False
# 3     False      False
# 4     False      False

# %%
combined = pd.concat([blue_df, red_df])

# %%
combined #have to group by opponent because we want the strikes absorbed/ how many times the fighter got knocked down or was put in a submission position etc in the last #x fights
# Out:
#            Date            Fighter              Opponent Winner   KD   STR  \
# 0    2025-07-26  Reinier de Ridder      Robert Whittaker   Blue  0.0  67.0
# 1    2025-07-26           Petr Yan         Marcus McGhee   Blue  0.0  81.0
# 2    2025-07-26    Shara Magomedov  Marc-Andre Barriault   Blue  0.0  93.0
# 3    2025-07-26      Asu Almabayev            Jose Ochoa   Blue  0.0  22.0
# 4    2025-07-26      Bogdan Guskov         Nikita Krylov   Blue  1.0  23.0
# ...         ...                ...                   ...    ...  ...   ...
# 8271 1994-03-11   Robert Lucarelli          Orlando Wiet   Blue  0.0   2.0
# 8272 1994-03-11    Thaddeus Luster         Frank Hamaker   Blue  0.0   0.0
# 8273 1994-03-11      David Levicki         Johnny Rhodes   Blue  0.0   4.0
# 8274 1994-03-11         Ray Wizard         Patrick Smith   Blue  0.0   1.0
# 8275 1994-03-11     Sean Daugherty          Scott Morris   Blue  0.0   0.0
#
#       SUB  Was_Blue  Is_Winner
# 0     0.0      True       True
# 1     0.0      True       True
# 2     0.0      True       True
# 3     2.0      True       True
# 4     0.0      True       True
# ...   ...       ...        ...
# 8271  1.0     False      False
# 8272  0.0     False      False
# 8273  0.0     False      False
# 8274  0.0     False      False
# 8275  0.0     False      False
#
# [16552 rows x 9 columns]

# %%
sorted_comb = combined.sort_values(by="Date", ascending=False)

# %%
sorted_comb[["Opponent", "KD", "STR", "SUB"]].groupby("Opponent").mean() #This table is how many knockdowns these fighters have taken in all their fights on average, average strikes absorbed and # of times been put in sub attempts.
# Out:
#                           KD        STR       SUB
# Opponent
# AJ Cunningham       0.500000  39.000000  0.500000
# AJ Dobson           0.250000  69.500000  0.000000
# AJ Fletcher         0.000000  55.000000  0.250000
# Aalon Cruz          0.500000  32.500000  0.000000
# Aaron Brink         0.000000   2.000000  2.000000
# ...                      ...        ...       ...
# Zhang Tiequan       0.500000  20.000000  1.250000
# Zhang Weili         0.166667  40.166667  0.250000
# Zubaira Tukhugov    0.000000  38.444444  0.222222
# Zviad Lazishvili    0.000000  92.000000  0.000000
# Zygimantas Ramaska  0.000000  14.000000  1.000000
#
# [2600 rows x 3 columns]

# %%
test = sorted_comb[["Opponent", "KD", "STR", "SUB"]].groupby("Opponent").rolling(3).mean()

# %%
sorted_comb[sorted_comb["Opponent"] == "Zhang Weili"][["STR"]]
# Out:
#         STR
# 253    12.0
# 657    43.0
# 984    24.0
# 1390    6.0
# 1621   43.0
# 1913   86.0
# 2198    5.0
# 2733  186.0
# 2989    4.0
# 3260   30.0
# 3401    9.0
# 3529   34.0

# %%
sorted_comb.head(15)
# Out:
#          Date               Fighter           Opponent Winner   KD   STR  SUB  \
# 0  2025-07-26     Reinier de Ridder   Robert Whittaker   Blue  0.0  67.0  0.0
# 1  2025-07-26              Petr Yan      Marcus McGhee   Blue  0.0  81.0  0.0
# 11 2025-07-26       Marcus Buchecha       Martin Buday   Blue  0.0  24.0  0.0
# 10 2025-07-26        Mohammad Yahya      Steven Nguyen   Blue  0.0  57.0  0.0
# 9  2025-07-26             Ibo Aslan      Billy Elekana   Blue  0.0  28.0  0.0
# 8  2025-07-26          Amanda Ribas      Tabatha Ricci   Blue  0.0  30.0  0.0
# 7  2025-07-26     Da'Mon Blackshear        Davey Grant   Blue  0.0  33.0  1.0
# 6  2025-07-26           Carlos Leal    Muslim Salikhov   Blue  0.0   5.0  0.0
# 5  2025-07-26     Said Nurmagomedov     Bryce Mitchell   Blue  1.0  20.0  1.0
# 4  2025-07-26         Nikita Krylov      Bogdan Guskov   Blue  0.0  16.0  0.0
# 3  2025-07-26            Jose Ochoa      Asu Almabayev   Blue  0.0  26.0  2.0
# 2  2025-07-26  Marc-Andre Barriault    Shara Magomedov   Blue  0.0  39.0  0.0
# 1  2025-07-26         Marcus McGhee           Petr Yan   Blue  0.0  64.0  0.0
# 0  2025-07-26      Robert Whittaker  Reinier de Ridder   Blue  1.0  66.0  0.0
# 6  2025-07-26       Muslim Salikhov        Carlos Leal   Blue  1.0   3.0  0.0
#
#     Was_Blue  Is_Winner
# 0       True       True
# 1       True       True
# 11     False      False
# 10     False      False
# 9      False      False
# 8      False      False
# 7      False      False
# 6      False      False
# 5      False      False
# 4      False      False
# 3      False      False
# 2      False      False
# 1      False      False
# 0      False      False
# 6       True       True

# %%
test = sorted_comb.copy()

# %%
test.drop(["Winner", "Was_Blue"], axis=1, inplace=True)

# %%
test[["Fighter", "Opponent"]] = test[["Opponent", "Fighter"]]
test.rename(columns = {"KD": "KD_Absorbed", "STR": "STR_Absorbed", "SUB": "SUB_Faced"}, inplace=True)
test["Is_Winner"] = ~test["Is_Winner"]

# %%
test
# Out:
#            Date           Fighter           Opponent  KD_Absorbed  \
# 0    2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
# 1    2025-07-26     Marcus McGhee           Petr Yan          0.0
# 11   2025-07-26      Martin Buday    Marcus Buchecha          0.0
# 10   2025-07-26     Steven Nguyen     Mohammad Yahya          0.0
# 9    2025-07-26     Billy Elekana          Ibo Aslan          0.0
# ...         ...               ...                ...          ...
# 8262 1994-03-11     Remco Pardoel       Royce Gracie          0.0
# 8263 1994-03-11     Johnny Rhodes      Patrick Smith          0.0
# 8264 1994-03-11     Jason DeLucia       Royce Gracie          0.0
# 8265 1994-03-11      Orlando Wiet      Remco Pardoel          0.0
# 8275 1994-03-11      Scott Morris     Sean Daugherty          0.0
#
#       STR_Absorbed  SUB_Faced  Is_Winner
# 0             67.0        0.0      False
# 1             81.0        0.0      False
# 11            24.0        0.0       True
# 10            57.0        0.0       True
# 9             28.0        0.0       True
# ...            ...        ...        ...
# 8262           0.0        1.0      False
# 8263           5.0        1.0      False
# 8264           0.0        1.0      False
# 8265           7.0        0.0      False
# 8275           0.0        0.0       True
#
# [16552 rows x 7 columns]

# %%
test["Last_Fight_Date"] = test.groupby("Fighter")["Date"].transform(lambda x: x.shift(-1))

# %%
test["Days_Since_Last_Fight"] = test["Date"] - test["Last_Fight_Date"]

# %%
test[test["Fighter"] == "Reinier de Ridder"]
# Out:
#           Date            Fighter            Opponent  KD_Absorbed  \
# 0   2025-07-26  Reinier de Ridder    Robert Whittaker          1.0
# 120 2025-05-03  Reinier de Ridder           Bo Nickal          0.0
# 279 2025-01-18  Reinier de Ridder       Kevin Holland          0.0
# 355 2024-11-09  Reinier de Ridder  Gerald Meerschaert          0.0
#
#      STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight
# 0            66.0        0.0       True      2025-05-03               84 days
# 120           8.0        0.0       True      2025-01-18              105 days
# 279          11.0        0.0       True      2024-11-09               70 days
# 355          30.0        0.0       True             NaT                   NaT

# %%
for i in ["KD_Absorbed", "STR_Absorbed", "SUB_Faced"]:
    test["Prev_" + i] = test.groupby("Fighter")[i].transform(lambda x: x.shift(-1))

# %%
test[test["Fighter"]== "Zhang Weili"]
# Out:
#            Date      Fighter            Opponent  KD_Absorbed  STR_Absorbed  \
# 253  2025-02-08  Zhang Weili      Tatiana Suarez          0.0          12.0
# 657  2024-04-13  Zhang Weili         Yan Xiaonan          1.0          43.0
# 984  2023-08-19  Zhang Weili        Amanda Lemos          0.0          24.0
# 1390 2022-11-12  Zhang Weili       Carla Esparza          0.0           6.0
# 1621 2022-06-11  Zhang Weili  Joanna Jedrzejczyk          0.0          43.0
# 1913 2021-11-06  Zhang Weili      Rose Namajunas          0.0          86.0
# 2198 2021-04-24  Zhang Weili      Rose Namajunas          1.0           5.0
# 2733 2020-03-07  Zhang Weili  Joanna Jedrzejczyk          0.0         186.0
# 2989 2019-08-31  Zhang Weili     Jessica Andrade          0.0           4.0
# 3260 2019-03-02  Zhang Weili    Tecia Pennington          0.0          30.0
# 3401 2018-11-24  Zhang Weili     Jessica Aguilar          0.0           9.0
# 3529 2018-08-04  Zhang Weili     Danielle Taylor          0.0          34.0
#
#       SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight  \
# 253         0.0       True      2024-04-13              301 days
# 657         0.0       True      2023-08-19              238 days
# 984         2.0       True      2022-11-12              280 days
# 1390        0.0       True      2022-06-11              154 days
# 1621        0.0       True      2021-11-06              217 days
# 1913        0.0      False      2021-04-24              196 days
# 2198        0.0      False      2020-03-07              413 days
# 2733        0.0       True      2019-08-31              189 days
# 2989        0.0       True      2019-03-02              182 days
# 3260        0.0       True      2018-11-24               98 days
# 3401        0.0       True      2018-08-04              112 days
# 3529        1.0       True             NaT                   NaT
#
#       Prev_KD_Absorbed  Prev_STR_Absorbed  Prev_SUB_Faced
# 253                1.0               43.0             0.0
# 657                0.0               24.0             2.0
# 984                0.0                6.0             0.0
# 1390               0.0               43.0             0.0
# 1621               0.0               86.0             0.0
# 1913               1.0                5.0             0.0
# 2198               0.0              186.0             0.0
# 2733               0.0                4.0             0.0
# 2989               0.0               30.0             0.0
# 3260               0.0                9.0             0.0
# 3401               0.0               34.0             1.0
# 3529               NaN                NaN             NaN

# %%
test2 = test.copy()

# %%
test2.reset_index(inplace=True)

# %%
len(test2)
# Out:
# 16552

# %%
(test2[test2["Days_Since_Last_Fight"].isna()]["Is_Winner"] == True).sum()
# Out:
# np.int64(1128)

# %%
for i in ["Prev_KD_Absorbed", "Prev_STR_Absorbed", "Prev_SUB_Faced"]:
    names = {"Prev_KD_Absorbed": "KD_Absorbed", "Prev_STR_Absorbed": "STR_Absorbed", "Prev_SUB_Faced": "SUB_Faced"}
    test2["Past_3_" + names[i]] = test2.groupby("Fighter", as_index = False)[i].rolling(3).mean()[i].shift(-2)

# %%
test2[test2["Fighter"] == "Robert Whittaker"]
# Out:
#        index       Date           Fighter           Opponent  KD_Absorbed  \
# 0          0 2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
# 761      379 2024-10-26  Robert Whittaker    Khamzat Chimaev          0.0
# 1124     558 2024-06-22  Robert Whittaker    Ikram Aliskerov          0.0
# 1531     758 2024-02-17  Robert Whittaker        Paulo Costa          0.0
# 2128    1061 2023-07-08  Robert Whittaker  Dricus Du Plessis          1.0
# 2981    1486 2022-09-03  Robert Whittaker     Marvin Vettori          0.0
# 3606    1802 2022-02-12  Robert Whittaker    Israel Adesanya          1.0
# 4421    2210 2021-04-17  Robert Whittaker    Kelvin Gastelum          0.0
# 4892    2442 2020-10-24  Robert Whittaker    Jared Cannonier          0.0
# 5187    2582 2020-07-25  Robert Whittaker        Darren Till          0.0
# 5865    2928 2019-10-05  Robert Whittaker    Israel Adesanya          2.0
# 7226    3606 2018-06-09  Robert Whittaker        Yoel Romero          2.0
# 8097    4038 2017-07-08  Robert Whittaker        Yoel Romero          0.0
# 8309    4147 2017-04-15  Robert Whittaker       Jacare Souza          0.0
# 8643    4321 2016-11-26  Robert Whittaker      Derek Brunson          0.0
# 9260    4622 2016-04-23  Robert Whittaker       Rafael Natal          0.0
# 9670    4829 2015-11-14  Robert Whittaker         Uriah Hall          0.0
# 10144   5070 2015-05-09  Robert Whittaker       Brad Tavares          0.0
# 10616   5309 2014-11-07  Robert Whittaker       Clint Hester          0.0
# 10977   5502 2014-06-28  Robert Whittaker        Mike Rhodes          0.0
# 11330   5667 2014-02-22  Robert Whittaker   Stephen Thompson          1.0
# 11784   5884 2013-08-28  Robert Whittaker        Court McGee          0.0
# 11934   5971 2013-05-25  Robert Whittaker       Colton Smith          1.0
# 12287   6141 2012-12-14  Robert Whittaker         Brad Scott          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 0              67.0        0.0      False      2024-10-26
# 761             3.0        1.0      False      2024-06-22
# 1124            5.0        0.0       True      2024-02-17
# 1531           67.0        0.0       True      2023-07-08
# 2128           62.0        0.0      False      2022-09-03
# 2981           33.0        0.0       True      2022-02-12
# 3606           79.0        0.0      False      2021-04-17
# 4421           62.0        0.0       True      2020-10-24
# 4892           53.0        0.0       True      2020-07-25
# 5187           41.0        0.0       True      2019-10-05
# 5865           40.0        0.0      False      2018-06-09
# 7226          111.0        0.0       True      2017-07-08
# 8097           48.0        0.0       True      2017-04-15
# 8309            9.0        0.0       True      2016-11-26
# 8643           19.0        0.0       True      2016-04-23
# 9260           62.0        0.0       True      2015-11-14
# 9670           45.0        0.0       True      2015-05-09
# 10144           2.0        0.0       True      2014-11-07
# 10616          28.0        0.0       True      2014-06-28
# 10977          47.0        0.0       True      2014-02-22
# 11330          38.0        0.0      False      2013-08-28
# 11784          88.0        0.0      False      2013-05-25
# 11934          33.0        1.0       True      2012-12-14
# 12287          55.0        0.0       True             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 0                  273 days               0.0                3.0
# 761                126 days               0.0                5.0
# 1124               126 days               0.0               67.0
# 1531               224 days               1.0               62.0
# 2128               308 days               0.0               33.0
# 2981               203 days               1.0               79.0
# 3606               301 days               0.0               62.0
# 4421               175 days               0.0               53.0
# 4892                91 days               0.0               41.0
# 5187               294 days               2.0               40.0
# 5865               483 days               2.0              111.0
# 7226               336 days               0.0               48.0
# 8097                84 days               0.0                9.0
# 8309               140 days               0.0               19.0
# 8643               217 days               0.0               62.0
# 9260               161 days               0.0               45.0
# 9670               189 days               0.0                2.0
# 10144              183 days               0.0               28.0
# 10616              132 days               0.0               47.0
# 10977              126 days               1.0               38.0
# 11330              178 days               0.0               88.0
# 11784               95 days               1.0               33.0
# 11934              162 days               0.0               55.0
# 12287                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0                 1.0            0.000000            25.000000
# 761               0.0            0.333333            44.666667
# 1124              0.0            0.333333            54.000000
# 1531              0.0            0.666667            58.000000
# 2128              0.0            0.333333            58.000000
# 2981              0.0            0.333333            64.666667
# 3606              0.0            0.000000            52.000000
# 4421              0.0            0.666667            44.666667
# 4892              0.0            1.333333            64.000000
# 5187              0.0            1.333333            66.333333
# 5865              0.0            0.666667            56.000000
# 7226              0.0            0.000000            25.333333
# 8097              0.0            0.000000            30.000000
# 8309              0.0            0.000000            42.000000
# 8643              0.0            0.000000            36.333333
# 9260              0.0            0.000000            25.000000
# 9670              0.0            0.000000            25.666667
# 10144             0.0            0.333333            37.666667
# 10616             0.0            0.333333            57.666667
# 10977             0.0            0.666667            53.000000
# 11330             0.0            0.333333            58.666667
# 11784             1.0                 NaN                  NaN
# 11934             0.0                 NaN                  NaN
# 12287             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced
# 0              0.333333
# 761            0.000000
# 1124           0.000000
# 1531           0.000000
# 2128           0.000000
# 2981           0.000000
# 3606           0.000000
# 4421           0.000000
# 4892           0.000000
# 5187           0.000000
# 5865           0.000000
# 7226           0.000000
# 8097           0.000000
# 8309           0.000000
# 8643           0.000000
# 9260           0.000000
# 9670           0.000000
# 10144          0.000000
# 10616          0.000000
# 10977          0.333333
# 11330          0.333333
# 11784               NaN
# 11934               NaN
# 12287               NaN

# %%
test2
# Out:
#        index       Date           Fighter           Opponent  KD_Absorbed  \
# 0          0 2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
# 1          1 2025-07-26     Marcus McGhee           Petr Yan          0.0
# 2         11 2025-07-26      Martin Buday    Marcus Buchecha          0.0
# 3         10 2025-07-26     Steven Nguyen     Mohammad Yahya          0.0
# 4          9 2025-07-26     Billy Elekana          Ibo Aslan          0.0
# ...      ...        ...               ...                ...          ...
# 16547   8262 1994-03-11     Remco Pardoel       Royce Gracie          0.0
# 16548   8263 1994-03-11     Johnny Rhodes      Patrick Smith          0.0
# 16549   8264 1994-03-11     Jason DeLucia       Royce Gracie          0.0
# 16550   8265 1994-03-11      Orlando Wiet      Remco Pardoel          0.0
# 16551   8275 1994-03-11      Scott Morris     Sean Daugherty          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 0              67.0        0.0      False      2024-10-26
# 1              81.0        0.0      False      2024-11-16
# 2              24.0        0.0       True      2025-04-05
# 3              57.0        0.0       True      2024-03-23
# 4              28.0        0.0       True      2025-01-18
# ...             ...        ...        ...             ...
# 16547           0.0        1.0      False             NaT
# 16548           5.0        1.0      False             NaT
# 16549           0.0        1.0      False             NaT
# 16550           7.0        0.0      False             NaT
# 16551           0.0        0.0       True             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 0                  273 days               0.0                3.0
# 1                  252 days               0.0               48.0
# 2                  112 days               0.0               36.0
# 3                  490 days               1.0              105.0
# 4                  189 days               0.0               47.0
# ...                     ...               ...                ...
# 16547                   NaT               NaN                NaN
# 16548                   NaT               NaN                NaN
# 16549                   NaT               NaN                NaN
# 16550                   NaT               NaN                NaN
# 16551                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0                 1.0                 0.0            25.000000
# 1                 0.0                 0.0            26.666667
# 2                 0.0                 0.0            53.000000
# 3                 0.0                 NaN                  NaN
# 4                 2.0                 NaN                  NaN
# ...               ...                 ...                  ...
# 16547             NaN                 NaN                  NaN
# 16548             NaN                 NaN                  NaN
# 16549             NaN                 NaN                  NaN
# 16550             NaN                 NaN                  NaN
# 16551             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced
# 0              0.333333
# 1              0.000000
# 2              0.000000
# 3                   NaN
# 4                   NaN
# ...                 ...
# 16547               NaN
# 16548               NaN
# 16549               NaN
# 16550               NaN
# 16551               NaN
#
# [16552 rows x 16 columns]

# %%
test2["Date"].hist() #"Modern age of UFC/MMA started in 2000 with the adoption of unified rules. I will cut out all fights before that."
# Out:
# <Axes: >

# %%
test2.to_csv("test2.csv")

# %%
test3 = test2.copy()

# %%
test3
# Out:
#        index       Date           Fighter           Opponent  KD_Absorbed  \
# 0          0 2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
# 1          1 2025-07-26     Marcus McGhee           Petr Yan          0.0
# 2         11 2025-07-26      Martin Buday    Marcus Buchecha          0.0
# 3         10 2025-07-26     Steven Nguyen     Mohammad Yahya          0.0
# 4          9 2025-07-26     Billy Elekana          Ibo Aslan          0.0
# ...      ...        ...               ...                ...          ...
# 16547   8262 1994-03-11     Remco Pardoel       Royce Gracie          0.0
# 16548   8263 1994-03-11     Johnny Rhodes      Patrick Smith          0.0
# 16549   8264 1994-03-11     Jason DeLucia       Royce Gracie          0.0
# 16550   8265 1994-03-11      Orlando Wiet      Remco Pardoel          0.0
# 16551   8275 1994-03-11      Scott Morris     Sean Daugherty          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 0              67.0        0.0      False      2024-10-26
# 1              81.0        0.0      False      2024-11-16
# 2              24.0        0.0       True      2025-04-05
# 3              57.0        0.0       True      2024-03-23
# 4              28.0        0.0       True      2025-01-18
# ...             ...        ...        ...             ...
# 16547           0.0        1.0      False             NaT
# 16548           5.0        1.0      False             NaT
# 16549           0.0        1.0      False             NaT
# 16550           7.0        0.0      False             NaT
# 16551           0.0        0.0       True             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 0                  273 days               0.0                3.0
# 1                  252 days               0.0               48.0
# 2                  112 days               0.0               36.0
# 3                  490 days               1.0              105.0
# 4                  189 days               0.0               47.0
# ...                     ...               ...                ...
# 16547                   NaT               NaN                NaN
# 16548                   NaT               NaN                NaN
# 16549                   NaT               NaN                NaN
# 16550                   NaT               NaN                NaN
# 16551                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0                 1.0                 0.0            25.000000
# 1                 0.0                 0.0            26.666667
# 2                 0.0                 0.0            53.000000
# 3                 0.0                 NaN                  NaN
# 4                 2.0                 NaN                  NaN
# ...               ...                 ...                  ...
# 16547             NaN                 NaN                  NaN
# 16548             NaN                 NaN                  NaN
# 16549             NaN                 NaN                  NaN
# 16550             NaN                 NaN                  NaN
# 16551             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced
# 0              0.333333
# 1              0.000000
# 2              0.000000
# 3                   NaN
# 4                   NaN
# ...                 ...
# 16547               NaN
# 16548               NaN
# 16549               NaN
# 16550               NaN
# 16551               NaN
#
# [16552 rows x 16 columns]

# %%
# test3 = test3[test3["Date"].dt.year >= 2000]

# %%
test3["UFC_Debut"] = test3["Last_Fight_Date"].isna()

# %%
test3[test3["Fighter"] == "Reinier de Ridder"]
# Out:
#      index       Date            Fighter            Opponent  KD_Absorbed  \
# 13       0 2025-07-26  Reinier de Ridder    Robert Whittaker          1.0
# 240    120 2025-05-03  Reinier de Ridder           Bo Nickal          0.0
# 565    279 2025-01-18  Reinier de Ridder       Kevin Holland          0.0
# 713    355 2024-11-09  Reinier de Ridder  Gerald Meerschaert          0.0
#
#      STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight  \
# 13           66.0        0.0       True      2025-05-03               84 days
# 240           8.0        0.0       True      2025-01-18              105 days
# 565          11.0        0.0       True      2024-11-09               70 days
# 713          30.0        0.0       True             NaT                   NaT
#
#      Prev_KD_Absorbed  Prev_STR_Absorbed  Prev_SUB_Faced  Past_3_KD_Absorbed  \
# 13                0.0                8.0             0.0                 0.0
# 240               0.0               11.0             0.0                 NaN
# 565               0.0               30.0             0.0                 NaN
# 713               NaN                NaN             NaN                 NaN
#
#      Past_3_STR_Absorbed  Past_3_SUB_Faced  UFC_Debut
# 13             16.333333               0.0      False
# 240                  NaN               NaN      False
# 565                  NaN               NaN      False
# 713                  NaN               NaN       True

# %%
test3["Prev_Fight_Result"] = test3.groupby("Fighter").transform(lambda x: x.shift(-1))["Is_Winner"]

# %%
test3
# Out:
#        index       Date           Fighter           Opponent  KD_Absorbed  \
# 0          0 2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
# 1          1 2025-07-26     Marcus McGhee           Petr Yan          0.0
# 2         11 2025-07-26      Martin Buday    Marcus Buchecha          0.0
# 3         10 2025-07-26     Steven Nguyen     Mohammad Yahya          0.0
# 4          9 2025-07-26     Billy Elekana          Ibo Aslan          0.0
# ...      ...        ...               ...                ...          ...
# 16547   8262 1994-03-11     Remco Pardoel       Royce Gracie          0.0
# 16548   8263 1994-03-11     Johnny Rhodes      Patrick Smith          0.0
# 16549   8264 1994-03-11     Jason DeLucia       Royce Gracie          0.0
# 16550   8265 1994-03-11      Orlando Wiet      Remco Pardoel          0.0
# 16551   8275 1994-03-11      Scott Morris     Sean Daugherty          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 0              67.0        0.0      False      2024-10-26
# 1              81.0        0.0      False      2024-11-16
# 2              24.0        0.0       True      2025-04-05
# 3              57.0        0.0       True      2024-03-23
# 4              28.0        0.0       True      2025-01-18
# ...             ...        ...        ...             ...
# 16547           0.0        1.0      False             NaT
# 16548           5.0        1.0      False             NaT
# 16549           0.0        1.0      False             NaT
# 16550           7.0        0.0      False             NaT
# 16551           0.0        0.0       True             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 0                  273 days               0.0                3.0
# 1                  252 days               0.0               48.0
# 2                  112 days               0.0               36.0
# 3                  490 days               1.0              105.0
# 4                  189 days               0.0               47.0
# ...                     ...               ...                ...
# 16547                   NaT               NaN                NaN
# 16548                   NaT               NaN                NaN
# 16549                   NaT               NaN                NaN
# 16550                   NaT               NaN                NaN
# 16551                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0                 1.0                 0.0            25.000000
# 1                 0.0                 0.0            26.666667
# 2                 0.0                 0.0            53.000000
# 3                 0.0                 NaN                  NaN
# 4                 2.0                 NaN                  NaN
# ...               ...                 ...                  ...
# 16547             NaN                 NaN                  NaN
# 16548             NaN                 NaN                  NaN
# 16549             NaN                 NaN                  NaN
# 16550             NaN                 NaN                  NaN
# 16551             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced  UFC_Debut Prev_Fight_Result
# 0              0.333333      False             False
# 1              0.000000      False              True
# 2              0.000000      False              True
# 3                   NaN      False             False
# 4                   NaN      False             False
# ...                 ...        ...               ...
# 16547               NaN       True               NaN
# 16548               NaN       True               NaN
# 16549               NaN       True               NaN
# 16550               NaN       True               NaN
# 16551               NaN       True               NaN
#
# [16552 rows x 18 columns]

# %%
# test3["Prev_3_Fight_Win_Rate"] = test3.groupby("Fighter", as_index=False)["Is_Winner"].rolling(3).mean()["Is_Winner"].shift(-3)
test3["Prev_3_Fight_Win_Rate"] = (test3.groupby("Fighter")["Prev_Fight_Result"].rolling(3).mean().shift(-2).reset_index(level=0, drop=True))

# %%
test3[test3["Fighter"] == "Max Holloway"]
# Out:
#        index       Date       Fighter               Opponent  KD_Absorbed  \
# 26        12 2025-07-19  Max Holloway         Dustin Poirier          1.0
# 762      378 2024-10-26  Max Holloway           Ilia Topuria          1.0
# 1322     658 2024-04-13  Max Holloway         Justin Gaethje          0.0
# 1941     970 2023-08-26  Max Holloway         Chan Sung Jung          0.0
# 2390    1190 2023-04-15  Max Holloway           Arnold Allen          0.0
# 3173    1583 2022-07-02  Max Holloway  Alexander Volkanovski          0.0
# 3808    1901 2021-11-13  Max Holloway         Yair Rodriguez          0.0
# 4705    2349 2021-01-16  Max Holloway          Calvin Kattar          0.0
# 5245    2621 2020-07-11  Max Holloway  Alexander Volkanovski          0.0
# 5660    2829 2019-12-14  Max Holloway  Alexander Volkanovski          0.0
# 6081    3037 2019-07-27  Max Holloway          Frankie Edgar          0.0
# 6410    3194 2019-04-13  Max Holloway         Dustin Poirier          0.0
# 6720    3356 2018-12-08  Max Holloway           Brian Ortega          0.0
# 7700    3839 2017-12-02  Max Holloway              Jose Aldo          0.0
# 8193    4096 2017-06-03  Max Holloway              Jose Aldo          0.0
# 8588    4285 2016-12-10  Max Holloway         Anthony Pettis          0.0
# 9142    4571 2016-06-04  Max Holloway          Ricardo Lamas          0.0
# 9542    4772 2015-12-12  Max Holloway        Jeremy Stephens          0.0
# 9804    4895 2015-08-23  Max Holloway       Charles Oliveira          0.0
# 10201   5095 2015-04-18  Max Holloway            Cub Swanson          0.0
# 10357   5173 2015-02-14  Max Holloway            Cole Miller          0.0
# 10695   5342 2014-10-04  Max Holloway        Akira Corassani          0.0
# 10843   5406 2014-08-23  Max Holloway           Clay Collard          0.0
# 11165   5582 2014-04-26  Max Holloway             Andre Fili          0.0
# 11456   5725 2014-01-04  Max Holloway             Will Chope          0.0
# 11786   5900 2013-08-17  Max Holloway         Conor McGregor          0.0
# 11941   5970 2013-05-25  Max Holloway        Dennis Bermudez          0.0
# 12244   6127 2012-12-29  Max Holloway         Leonard Garcia          0.0
# 12454   6231 2012-08-11  Max Holloway        Justin Lawrence          0.0
# 12644   6318 2012-06-01  Max Holloway          Pat Schilling          0.0
# 12835   6422 2012-02-04  Max Holloway         Dustin Poirier          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 26            109.0        1.0       True      2024-10-26
# 762            75.0        0.0      False      2024-04-13
# 1322          103.0        0.0       True      2023-08-26
# 1941           34.0        0.0       True      2023-04-15
# 2390           76.0        0.0       True      2022-07-02
# 3173          199.0        0.0      False      2021-11-13
# 3808          159.0        0.0       True      2021-01-16
# 4705          133.0        0.0       True      2020-07-11
# 5245          137.0        0.0      False      2019-12-14
# 5660          157.0        0.0      False      2019-07-27
# 6081           96.0        0.0       True      2019-04-13
# 6410          178.0        0.0      False      2018-12-08
# 6720          110.0        0.0       True      2017-12-02
# 7700           87.0        0.0       True      2017-06-03
# 8193           55.0        0.0       True      2016-12-10
# 8588           53.0        0.0       True      2016-06-04
# 9142           64.0        0.0       True      2015-12-12
# 9542           47.0        0.0       True      2015-08-23
# 9804            5.0        0.0       True      2015-04-18
# 10201          56.0        0.0       True      2015-02-14
# 10357          31.0        0.0       True      2014-10-04
# 10695          11.0        0.0       True      2014-08-23
# 10843          70.0        0.0       True      2014-04-26
# 11165          44.0        0.0       True      2014-01-04
# 11456          33.0        0.0       True      2013-08-17
# 11786          53.0        0.0      False      2013-05-25
# 11941          73.0        0.0      False      2012-12-29
# 12244          89.0        0.0       True      2012-08-11
# 12454          32.0        0.0       True      2012-06-01
# 12644          27.0        0.0       True      2012-02-04
# 12835          11.0        3.0      False             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 26                 266 days               1.0               75.0
# 762                196 days               0.0              103.0
# 1322               231 days               0.0               34.0
# 1941               133 days               0.0               76.0
# 2390               287 days               0.0              199.0
# 3173               231 days               0.0              159.0
# 3808               301 days               0.0              133.0
# 4705               189 days               0.0              137.0
# 5245               210 days               0.0              157.0
# 5660               140 days               0.0               96.0
# 6081               105 days               0.0              178.0
# 6410               126 days               0.0              110.0
# 6720               371 days               0.0               87.0
# 7700               182 days               0.0               55.0
# 8193               175 days               0.0               53.0
# 8588               189 days               0.0               64.0
# 9142               175 days               0.0               47.0
# 9542               111 days               0.0                5.0
# 9804               127 days               0.0               56.0
# 10201               63 days               0.0               31.0
# 10357              133 days               0.0               11.0
# 10695               42 days               0.0               70.0
# 10843              119 days               0.0               44.0
# 11165              112 days               0.0               33.0
# 11456              140 days               0.0               53.0
# 11786               84 days               0.0               73.0
# 11941              147 days               0.0               89.0
# 12244              140 days               0.0               32.0
# 12454               71 days               0.0               27.0
# 12644              118 days               0.0               11.0
# 12835                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 26                0.0            0.333333            70.666667
# 762               0.0            0.000000            71.000000
# 1322              0.0            0.000000           103.000000
# 1941              0.0            0.000000           144.666667
# 2390              0.0            0.000000           163.666667
# 3173              0.0            0.000000           143.000000
# 3808              0.0            0.000000           142.333333
# 4705              0.0            0.000000           130.000000
# 5245              0.0            0.000000           143.666667
# 5660              0.0            0.000000           128.000000
# 6081              0.0            0.000000           125.000000
# 6410              0.0            0.000000            84.000000
# 6720              0.0            0.000000            65.000000
# 7700              0.0            0.000000            57.333333
# 8193              0.0            0.000000            54.666667
# 8588              0.0            0.000000            38.666667
# 9142              0.0            0.000000            36.000000
# 9542              0.0            0.000000            30.666667
# 9804              0.0            0.000000            32.666667
# 10201             0.0            0.000000            37.333333
# 10357             0.0            0.000000            41.666667
# 10695             0.0            0.000000            49.000000
# 10843             0.0            0.000000            43.333333
# 11165             0.0            0.000000            53.000000
# 11456             0.0            0.000000            71.666667
# 11786             0.0            0.000000            64.666667
# 11941             0.0            0.000000            49.333333
# 12244             0.0            0.000000            23.333333
# 12454             0.0                 NaN                  NaN
# 12644             3.0                 NaN                  NaN
# 12835             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced  UFC_Debut Prev_Fight_Result  Prev_3_Fight_Win_Rate
# 26                  0.0      False             False               0.666667
# 762                 0.0      False              True               1.000000
# 1322                0.0      False              True               0.666667
# 1941                0.0      False              True               0.666667
# 2390                0.0      False             False               0.666667
# 3173                0.0      False              True               0.666667
# 3808                0.0      False              True               0.333333
# 4705                0.0      False             False               0.333333
# 5245                0.0      False             False               0.333333
# 5660                0.0      False              True               0.666667
# 6081                0.0      False             False               0.666667
# 6410                0.0      False              True               1.000000
# 6720                0.0      False              True               1.000000
# 7700                0.0      False              True               1.000000
# 8193                0.0      False              True               1.000000
# 8588                0.0      False              True               1.000000
# 9142                0.0      False              True               1.000000
# 9542                0.0      False              True               1.000000
# 9804                0.0      False              True               1.000000
# 10201               0.0      False              True               1.000000
# 10357               0.0      False              True               1.000000
# 10695               0.0      False              True               1.000000
# 10843               0.0      False              True               0.666667
# 11165               0.0      False              True               0.333333
# 11456               0.0      False             False               0.333333
# 11786               0.0      False             False               0.666667
# 11941               0.0      False              True               1.000000
# 12244               1.0      False              True               0.666667
# 12454               NaN      False              True                    NaN
# 12644               NaN      False             False                    NaN
# 12835               NaN       True               NaN                    NaN

# %%
test3.rename(columns={"Prev_Fight_Result": "Won_Last_Fight"}, inplace=True)

# %%
test3[test3["Fighter"] == "Reinier de Ridder"]
# Out:
#      index       Date            Fighter            Opponent  KD_Absorbed  \
# 13       0 2025-07-26  Reinier de Ridder    Robert Whittaker          1.0
# 240    120 2025-05-03  Reinier de Ridder           Bo Nickal          0.0
# 565    279 2025-01-18  Reinier de Ridder       Kevin Holland          0.0
# 713    355 2024-11-09  Reinier de Ridder  Gerald Meerschaert          0.0
#
#      STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight  \
# 13           66.0        0.0       True      2025-05-03               84 days
# 240           8.0        0.0       True      2025-01-18              105 days
# 565          11.0        0.0       True      2024-11-09               70 days
# 713          30.0        0.0       True             NaT                   NaT
#
#      Prev_KD_Absorbed  Prev_STR_Absorbed  Prev_SUB_Faced  Past_3_KD_Absorbed  \
# 13                0.0                8.0             0.0                 0.0
# 240               0.0               11.0             0.0                 NaN
# 565               0.0               30.0             0.0                 NaN
# 713               NaN                NaN             NaN                 NaN
#
#      Past_3_STR_Absorbed  Past_3_SUB_Faced  UFC_Debut Won_Last_Fight  \
# 13             16.333333               0.0      False           True
# 240                  NaN               NaN      False           True
# 565                  NaN               NaN      False           True
# 713                  NaN               NaN       True            NaN
#
#      Prev_3_Fight_Win_Rate
# 13                     1.0
# 240                    NaN
# 565                    NaN
# 713                    NaN

# %%
test3.to_csv("test3.csv")

# %%
test4 = test3.copy()

# %%
test4[test4["Fighter"] == "Reinier de Ridder"]
# Out:
#      index       Date            Fighter            Opponent  KD_Absorbed  \
# 13       0 2025-07-26  Reinier de Ridder    Robert Whittaker          1.0
# 240    120 2025-05-03  Reinier de Ridder           Bo Nickal          0.0
# 565    279 2025-01-18  Reinier de Ridder       Kevin Holland          0.0
# 713    355 2024-11-09  Reinier de Ridder  Gerald Meerschaert          0.0
#
#      STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight  \
# 13           66.0        0.0       True      2025-05-03               84 days
# 240           8.0        0.0       True      2025-01-18              105 days
# 565          11.0        0.0       True      2024-11-09               70 days
# 713          30.0        0.0       True             NaT                   NaT
#
#      Prev_KD_Absorbed  Prev_STR_Absorbed  Prev_SUB_Faced  Past_3_KD_Absorbed  \
# 13                0.0                8.0             0.0                 0.0
# 240               0.0               11.0             0.0                 NaN
# 565               0.0               30.0             0.0                 NaN
# 713               NaN                NaN             NaN                 NaN
#
#      Past_3_STR_Absorbed  Past_3_SUB_Faced  UFC_Debut Won_Last_Fight  \
# 13             16.333333               0.0      False           True
# 240                  NaN               NaN      False           True
# 565                  NaN               NaN      False           True
# 713                  NaN               NaN       True            NaN
#
#      Prev_3_Fight_Win_Rate
# 13                     1.0
# 240                    NaN
# 565                    NaN
# 713                    NaN

# %%
test4 = test4.sort_values("Date", ascending=True)

# %%
test4["Is_Winner"] = test4["Is_Winner"] == 1.0

# %%
test4
# Out:
#        index       Date               Fighter            Opponent  \
# 16551   8275 1994-03-11          Scott Morris      Sean Daugherty
# 16522   8270 1994-03-11         Remco Pardoel  Alberta Cerra Leon
# 16523   8271 1994-03-11          Orlando Wiet    Robert Lucarelli
# 16524   8268 1994-03-11          Royce Gracie     Minoki Ichihara
# 16525   8267 1994-03-11         Patrick Smith        Scott Morris
# ...      ...        ...                   ...                 ...
# 21         4 2025-07-26         Nikita Krylov       Bogdan Guskov
# 22         3 2025-07-26            Jose Ochoa       Asu Almabayev
# 23         2 2025-07-26  Marc-Andre Barriault     Shara Magomedov
# 12         1 2025-07-26              Petr Yan       Marcus McGhee
# 0          0 2025-07-26      Robert Whittaker   Reinier de Ridder
#
#        KD_Absorbed  STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 16551          0.0           0.0        0.0       True             NaT
# 16522          0.0           1.0        0.0       True      1994-03-11
# 16523          0.0           2.0        1.0       True      1994-03-11
# 16524          0.0           3.0        0.0       True      1994-03-11
# 16525          0.0           0.0        0.0       True      1994-03-11
# ...            ...           ...        ...        ...             ...
# 21             1.0          23.0        0.0      False      2025-04-12
# 22             0.0          22.0        2.0      False      2025-06-14
# 23             0.0          93.0        0.0      False      2025-05-10
# 12             0.0          64.0        0.0       True      2024-11-23
# 0              0.0          67.0        0.0      False      2024-10-26
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 16551                   NaT               NaN                NaN
# 16522                0 days               0.0                1.0
# 16523                0 days               0.0                7.0
# 16524                0 days               0.0                0.0
# 16525                0 days               0.0                4.0
# ...                     ...               ...                ...
# 21                 105 days               1.0                8.0
# 22                  42 days               0.0                9.0
# 23                  77 days               0.0                6.0
# 12                 245 days               0.0               53.0
# 0                  273 days               0.0                3.0
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 16551             NaN                 NaN                  NaN
# 16522             0.0                 NaN                  NaN
# 16523             0.0                 NaN                  NaN
# 16524             0.0            0.000000             0.333333
# 16525             0.0            0.000000             3.000000
# ...               ...                 ...                  ...
# 21                0.0            0.333333            18.333333
# 22                0.0                 NaN                  NaN
# 23                0.0            0.666667             9.000000
# 12                0.0            0.000000            95.333333
# 0                 1.0            0.000000            25.000000
#
#        Past_3_SUB_Faced  UFC_Debut Won_Last_Fight  Prev_3_Fight_Win_Rate
# 16551               NaN       True            NaN                    NaN
# 16522               NaN      False           True                    NaN
# 16523               NaN      False          False                    NaN
# 16524          0.000000      False           True               1.000000
# 16525          0.000000      False           True               0.666667
# ...                 ...        ...            ...                    ...
# 21             0.333333      False          False               0.666667
# 22                  NaN      False           True                    NaN
# 23             0.333333      False           True               0.333333
# 12             0.000000      False           True               0.666667
# 0              0.333333      False          False               0.666667
#
# [16552 rows x 19 columns]

# %%
test4["Won_Last_Fight"] = test4["Won_Last_Fight"] == True

# %%
test4[test4["Fighter"] == "Marc-Andre Barriault"].sort_values("Date", ascending=False)
# Out:
#       index       Date               Fighter            Opponent  KD_Absorbed  \
# 23        2 2025-07-26  Marc-Andre Barriault     Shara Magomedov          0.0
# 222     116 2025-05-10  Marc-Andre Barriault         Bruno Silva          0.0
# 731     369 2024-11-02  Marc-Andre Barriault    Dustin Stoltzfus          1.0
# 1098    550 2024-06-29  Marc-Andre Barriault           Joe Pyfer          1.0
# 1600    799 2024-01-20  Marc-Andre Barriault        Chris Curtis          0.0
# 2233   1113 2023-06-10  Marc-Andre Barriault         Eryk Anders          0.0
# 2509   1262 2023-03-04  Marc-Andre Barriault      Julian Marquez          0.0
# 2937   1464 2022-09-17  Marc-Andre Barriault   Anthony Hernandez          0.0
# 3398   1695 2022-04-23  Marc-Andre Barriault       Jordan Wright          0.0
# 3641   1824 2022-02-05  Marc-Andre Barriault      Chidi Njokuani          1.0
# 4041   2020 2021-09-04  Marc-Andre Barriault  Dalcha Lungiambula          0.0
# 4476   2242 2021-03-27  Marc-Andre Barriault         Abu Azaitar          0.0
# 5295   2650 2020-06-20  Marc-Andre Barriault      Oskar Piechota          0.0
# 5648   2819 2019-12-21  Marc-Andre Barriault        JunYong Park          0.0
# 6088   3041 2019-07-27  Marc-Andre Barriault     Krzysztof Jotko          0.0
# 6322   3163 2019-05-04  Marc-Andre Barriault      Andrew Sanchez          0.0
#
#       STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 23            93.0        0.0      False      2025-05-10
# 222            6.0        0.0       True      2024-11-02
# 731           13.0        1.0      False      2024-06-29
# 1098           8.0        0.0      False      2024-01-20
# 1600         140.0        0.0      False      2023-06-10
# 2233          83.0        0.0       True      2023-03-04
# 2509          82.0        0.0       True      2022-09-17
# 2937          39.0        2.0      False      2022-04-23
# 3398          12.0        0.0       True      2022-02-05
# 3641          11.0        0.0      False      2021-09-04
# 4041          85.0        0.0       True      2021-03-27
# 4476         108.0        0.0       True      2020-06-20
# 5295          37.0        0.0       True      2019-12-21
# 5648          77.0        0.0      False      2019-07-27
# 6088          40.0        0.0      False      2019-05-04
# 6322          72.0        0.0      False             NaT
#
#      Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 23                 77 days               0.0                6.0
# 222               189 days               1.0               13.0
# 731               126 days               1.0                8.0
# 1098              161 days               0.0              140.0
# 1600              224 days               0.0               83.0
# 2233               98 days               0.0               82.0
# 2509              168 days               0.0               39.0
# 2937              147 days               0.0               12.0
# 3398               77 days               1.0               11.0
# 3641              154 days               0.0               85.0
# 4041              161 days               0.0              108.0
# 4476              280 days               0.0               37.0
# 5295              182 days               0.0               77.0
# 5648              147 days               0.0               40.0
# 6088               84 days               0.0               72.0
# 6322                   NaT               NaN                NaN
#
#       Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 23               0.0            0.666667             9.000000
# 222              1.0            0.666667            53.666667
# 731              0.0            0.333333            77.000000
# 1098             0.0            0.000000           101.666667
# 1600             0.0            0.000000            68.000000
# 2233             0.0            0.000000            44.333333
# 2509             2.0            0.333333            20.666667
# 2937             0.0            0.333333            36.000000
# 3398             0.0            0.333333            68.000000
# 3641             0.0            0.000000            76.666667
# 4041             0.0            0.000000            74.000000
# 4476             0.0            0.000000            51.333333
# 5295             0.0            0.000000            63.000000
# 5648             0.0                 NaN                  NaN
# 6088             0.0                 NaN                  NaN
# 6322             NaN                 NaN                  NaN
#
#       Past_3_SUB_Faced  UFC_Debut  Won_Last_Fight  Prev_3_Fight_Win_Rate
# 23            0.333333      False            True               0.333333
# 222           0.333333      False           False               0.000000
# 731           0.000000      False           False               0.333333
# 1098          0.000000      False           False               0.666667
# 1600          0.666667      False            True               0.666667
# 2233          0.666667      False            True               0.666667
# 2509          0.666667      False           False               0.333333
# 2937          0.000000      False            True               0.666667
# 3398          0.000000      False           False               0.666667
# 3641          0.000000      False            True               1.000000
# 4041          0.000000      False            True               0.666667
# 4476          0.000000      False            True               0.333333
# 5295          0.000000      False           False               0.000000
# 5648               NaN      False           False                    NaN
# 6088               NaN      False           False                    NaN
# 6322               NaN       True           False                    NaN

# %%
test4["Wins_Before_Fight"] = test4[["Fighter", "Won_Last_Fight"]].groupby("Fighter").cumsum()

# %%
test4.sort_values("Date", ascending=False)
# Out:
#        index       Date             Fighter           Opponent  KD_Absorbed  \
# 0          0 2025-07-26    Robert Whittaker  Reinier de Ridder          0.0
# 18         8 2025-07-26        Amanda Ribas      Tabatha Ricci          0.0
# 9          4 2025-07-26       Bogdan Guskov      Nikita Krylov          0.0
# 8          5 2025-07-26      Bryce Mitchell  Said Nurmagomedov          1.0
# 7          6 2025-07-26     Muslim Salikhov        Carlos Leal          0.0
# ...      ...        ...                 ...                ...          ...
# 16540   8272 1994-03-11     Thaddeus Luster      Frank Hamaker          0.0
# 16539   8273 1994-03-11       David Levicki      Johnny Rhodes          0.0
# 16538   8274 1994-03-11          Ray Wizard      Patrick Smith          0.0
# 16543   8270 1994-03-11  Alberta Cerra Leon      Remco Pardoel          0.0
# 16551   8275 1994-03-11        Scott Morris     Sean Daugherty          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 0              67.0        0.0      False      2024-10-26
# 18             34.0        0.0      False      2025-01-11
# 9              16.0        0.0       True      2025-01-18
# 8              20.0        1.0       True      2025-04-12
# 7               5.0        0.0       True      2024-11-23
# ...             ...        ...        ...             ...
# 16540           2.0        3.0      False             NaT
# 16539          11.0        0.0      False             NaT
# 16538           1.0        1.0      False             NaT
# 16543           4.0        1.0      False             NaT
# 16551           0.0        0.0       True             NaT
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 0                  273 days               0.0                3.0
# 18                 196 days               0.0               27.0
# 9                  189 days               0.0               20.0
# 8                  105 days               1.0               27.0
# 7                  245 days               0.0                9.0
# ...                     ...               ...                ...
# 16540                   NaT               NaN                NaN
# 16539                   NaT               NaN                NaN
# 16538                   NaT               NaN                NaN
# 16543                   NaT               NaN                NaN
# 16551                   NaT               NaN                NaN
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0                 1.0            0.000000            25.000000
# 18                1.0            0.000000            58.333333
# 9                 0.0            0.000000            17.333333
# 8                 3.0            0.666667            11.666667
# 7                 0.0            0.333333            21.000000
# ...               ...                 ...                  ...
# 16540             NaN                 NaN                  NaN
# 16539             NaN                 NaN                  NaN
# 16538             NaN                 NaN                  NaN
# 16543             NaN                 NaN                  NaN
# 16551             NaN                 NaN                  NaN
#
#        Past_3_SUB_Faced  UFC_Debut  Won_Last_Fight  Prev_3_Fight_Win_Rate  \
# 0              0.333333      False           False               0.666667
# 18             0.333333      False           False               0.333333
# 9              0.333333      False            True               1.000000
# 8              1.333333      False           False               0.333333
# 7              0.000000      False            True               0.666667
# ...                 ...        ...             ...                    ...
# 16540               NaN       True           False                    NaN
# 16539               NaN       True           False                    NaN
# 16538               NaN       True           False                    NaN
# 16543               NaN       True           False                    NaN
# 16551               NaN       True           False                    NaN
#
#        Wins_Before_Fight
# 0                     17
# 18                     7
# 9                      3
# 8                      8
# 7                      8
# ...                  ...
# 16540                  0
# 16539                  0
# 16538                  0
# 16543                  0
# 16551                  0
#
# [16552 rows x 20 columns]

# %%
test4[test4["Fighter"] == "Kevin Randleman"]
# Out:
#        index       Date          Fighter       Opponent  KD_Absorbed  \
# 16166   8085 1999-03-05  Kevin Randleman  Maurice Smith          0.0
# 16156   8075 1999-05-07  Kevin Randleman     Bas Rutten          0.0
# 16111   8052 1999-11-19  Kevin Randleman  Pete Williams          1.0
# 16071   8031 2000-06-09  Kevin Randleman    Pedro Rizzo          0.0
# 16033   8016 2000-11-17  Kevin Randleman  Randy Couture          0.0
# 15986   7995 2001-05-04  Kevin Randleman  Chuck Liddell          1.0
# 15934   7966 2002-01-11  Kevin Randleman  Renato Sobral          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 16166           9.0        2.0       True             NaT
# 16156          18.0        1.0      False      1999-03-05
# 16111           8.0        1.0       True      1999-05-07
# 16071          12.0        0.0       True      1999-11-19
# 16033          28.0        1.0      False      2000-06-09
# 15986           3.0        0.0      False      2000-11-17
# 15934           2.0        5.0       True      2001-05-04
#
#       Days_Since_Last_Fight  Prev_KD_Absorbed  Prev_STR_Absorbed  \
# 16166                   NaT               NaN                NaN
# 16156               63 days               0.0                9.0
# 16111              196 days               0.0               18.0
# 16071              203 days               1.0                8.0
# 16033              161 days               0.0               12.0
# 15986              168 days               0.0               28.0
# 15934              252 days               1.0                3.0
#
#        Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 16166             NaN                 NaN                  NaN
# 16156             2.0                 NaN                  NaN
# 16111             1.0                 NaN                  NaN
# 16071             1.0            0.333333            11.666667
# 16033             0.0            0.333333            12.666667
# 15986             1.0            0.333333            16.000000
# 15934             0.0            0.333333            14.333333
#
#        Past_3_SUB_Faced  UFC_Debut  Won_Last_Fight  Prev_3_Fight_Win_Rate  \
# 16166               NaN       True           False                    NaN
# 16156               NaN      False            True                    NaN
# 16111               NaN      False           False                    NaN
# 16071          1.333333      False            True               0.666667
# 16033          0.666667      False            True               0.666667
# 15986          0.666667      False           False               0.666667
# 15934          0.333333      False           False               0.333333
#
#        Wins_Before_Fight
# 16166                  0
# 16156                  1
# 16111                  1
# 16071                  2
# 16033                  3
# 15986                  3
# 15934                  3

# %%
test4.loc[test4["UFC_Debut"] == True, "Won_Last_Fight"] = True
test4["Lost_Last_Fight"] = test4["Won_Last_Fight"] == False

# %%
test4["Losses_Before_Fight"]= test4[["Fighter", "Lost_Last_Fight"]].groupby("Fighter").cumsum()

# %%
test4[test4["Fighter"] == "Robert Whittaker"]
# Out:
#        index       Date           Fighter           Opponent  KD_Absorbed  \
# 12287   6141 2012-12-14  Robert Whittaker         Brad Scott          0.0
# 11934   5971 2013-05-25  Robert Whittaker       Colton Smith          1.0
# 11784   5884 2013-08-28  Robert Whittaker        Court McGee          0.0
# 11330   5667 2014-02-22  Robert Whittaker   Stephen Thompson          1.0
# 10977   5502 2014-06-28  Robert Whittaker        Mike Rhodes          0.0
# 10616   5309 2014-11-07  Robert Whittaker       Clint Hester          0.0
# 10144   5070 2015-05-09  Robert Whittaker       Brad Tavares          0.0
# 9670    4829 2015-11-14  Robert Whittaker         Uriah Hall          0.0
# 9260    4622 2016-04-23  Robert Whittaker       Rafael Natal          0.0
# 8643    4321 2016-11-26  Robert Whittaker      Derek Brunson          0.0
# 8309    4147 2017-04-15  Robert Whittaker       Jacare Souza          0.0
# 8097    4038 2017-07-08  Robert Whittaker        Yoel Romero          0.0
# 7226    3606 2018-06-09  Robert Whittaker        Yoel Romero          2.0
# 5865    2928 2019-10-05  Robert Whittaker    Israel Adesanya          2.0
# 5187    2582 2020-07-25  Robert Whittaker        Darren Till          0.0
# 4892    2442 2020-10-24  Robert Whittaker    Jared Cannonier          0.0
# 4421    2210 2021-04-17  Robert Whittaker    Kelvin Gastelum          0.0
# 3606    1802 2022-02-12  Robert Whittaker    Israel Adesanya          1.0
# 2981    1486 2022-09-03  Robert Whittaker     Marvin Vettori          0.0
# 2128    1061 2023-07-08  Robert Whittaker  Dricus Du Plessis          1.0
# 1531     758 2024-02-17  Robert Whittaker        Paulo Costa          0.0
# 1124     558 2024-06-22  Robert Whittaker    Ikram Aliskerov          0.0
# 761      379 2024-10-26  Robert Whittaker    Khamzat Chimaev          0.0
# 0          0 2025-07-26  Robert Whittaker  Reinier de Ridder          0.0
#
#        STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date  \
# 12287          55.0        0.0       True             NaT
# 11934          33.0        1.0       True      2012-12-14
# 11784          88.0        0.0      False      2013-05-25
# 11330          38.0        0.0      False      2013-08-28
# 10977          47.0        0.0       True      2014-02-22
# 10616          28.0        0.0       True      2014-06-28
# 10144           2.0        0.0       True      2014-11-07
# 9670           45.0        0.0       True      2015-05-09
# 9260           62.0        0.0       True      2015-11-14
# 8643           19.0        0.0       True      2016-04-23
# 8309            9.0        0.0       True      2016-11-26
# 8097           48.0        0.0       True      2017-04-15
# 7226          111.0        0.0       True      2017-07-08
# 5865           40.0        0.0      False      2018-06-09
# 5187           41.0        0.0       True      2019-10-05
# 4892           53.0        0.0       True      2020-07-25
# 4421           62.0        0.0       True      2020-10-24
# 3606           79.0        0.0      False      2021-04-17
# 2981           33.0        0.0       True      2022-02-12
# 2128           62.0        0.0      False      2022-09-03
# 1531           67.0        0.0       True      2023-07-08
# 1124            5.0        0.0       True      2024-02-17
# 761             3.0        1.0      False      2024-06-22
# 0              67.0        0.0      False      2024-10-26
#
#       Days_Since_Last_Fight  ...  Prev_SUB_Faced  Past_3_KD_Absorbed  \
# 12287                   NaT  ...             NaN                 NaN
# 11934              162 days  ...             0.0                 NaN
# 11784               95 days  ...             1.0                 NaN
# 11330              178 days  ...             0.0            0.333333
# 10977              126 days  ...             0.0            0.666667
# 10616              132 days  ...             0.0            0.333333
# 10144              183 days  ...             0.0            0.333333
# 9670               189 days  ...             0.0            0.000000
# 9260               161 days  ...             0.0            0.000000
# 8643               217 days  ...             0.0            0.000000
# 8309               140 days  ...             0.0            0.000000
# 8097                84 days  ...             0.0            0.000000
# 7226               336 days  ...             0.0            0.000000
# 5865               483 days  ...             0.0            0.666667
# 5187               294 days  ...             0.0            1.333333
# 4892                91 days  ...             0.0            1.333333
# 4421               175 days  ...             0.0            0.666667
# 3606               301 days  ...             0.0            0.000000
# 2981               203 days  ...             0.0            0.333333
# 2128               308 days  ...             0.0            0.333333
# 1531               224 days  ...             0.0            0.666667
# 1124               126 days  ...             0.0            0.333333
# 761                126 days  ...             0.0            0.333333
# 0                  273 days  ...             1.0            0.000000
#
#        Past_3_STR_Absorbed  Past_3_SUB_Faced  UFC_Debut  Won_Last_Fight  \
# 12287                  NaN               NaN       True            True
# 11934                  NaN               NaN      False            True
# 11784                  NaN               NaN      False            True
# 11330            58.666667          0.333333      False           False
# 10977            53.000000          0.333333      False           False
# 10616            57.666667          0.000000      False            True
# 10144            37.666667          0.000000      False            True
# 9670             25.666667          0.000000      False            True
# 9260             25.000000          0.000000      False            True
# 8643             36.333333          0.000000      False            True
# 8309             42.000000          0.000000      False            True
# 8097             30.000000          0.000000      False            True
# 7226             25.333333          0.000000      False            True
# 5865             56.000000          0.000000      False            True
# 5187             66.333333          0.000000      False           False
# 4892             64.000000          0.000000      False            True
# 4421             44.666667          0.000000      False            True
# 3606             52.000000          0.000000      False            True
# 2981             64.666667          0.000000      False           False
# 2128             58.000000          0.000000      False            True
# 1531             58.000000          0.000000      False           False
# 1124             54.000000          0.000000      False            True
# 761              44.666667          0.000000      False            True
# 0                25.000000          0.333333      False           False
#
#        Prev_3_Fight_Win_Rate  Wins_Before_Fight  Lost_Last_Fight  \
# 12287                    NaN                  0            False
# 11934                    NaN                  1            False
# 11784                    NaN                  2            False
# 11330               0.666667                  2             True
# 10977               0.333333                  2             True
# 10616               0.333333                  3            False
# 10144               0.666667                  4            False
# 9670                1.000000                  5            False
# 9260                1.000000                  6            False
# 8643                1.000000                  7            False
# 8309                1.000000                  8            False
# 8097                1.000000                  9            False
# 7226                1.000000                 10            False
# 5865                1.000000                 11            False
# 5187                0.666667                 11             True
# 4892                0.666667                 12            False
# 4421                0.666667                 13            False
# 3606                1.000000                 14            False
# 2981                0.666667                 14             True
# 2128                0.666667                 15            False
# 1531                0.333333                 15             True
# 1124                0.666667                 16            False
# 761                 0.666667                 17            False
# 0                   0.666667                 17             True
#
#        Losses_Before_Fight
# 12287                    0
# 11934                    0
# 11784                    0
# 11330                    1
# 10977                    2
# 10616                    2
# 10144                    2
# 9670                     2
# 9260                     2
# 8643                     2
# 8309                     2
# 8097                     2
# 7226                     2
# 5865                     2
# 5187                     3
# 4892                     3
# 4421                     3
# 3606                     3
# 2981                     4
# 2128                     4
# 1531                     5
# 1124                     5
# 761                      5
# 0                        6
#
# [24 rows x 22 columns]

# %%
test4.sort_values("Date", ascending=False, inplace=True)

# %%
test4.head(15)
# Out:
#     index       Date            Fighter              Opponent  KD_Absorbed  \
# 0       0 2025-07-26   Robert Whittaker     Reinier de Ridder          0.0
# 18      8 2025-07-26       Amanda Ribas         Tabatha Ricci          0.0
# 9       4 2025-07-26      Bogdan Guskov         Nikita Krylov          0.0
# 8       5 2025-07-26     Bryce Mitchell     Said Nurmagomedov          1.0
# 7       6 2025-07-26    Muslim Salikhov           Carlos Leal          0.0
# 6       7 2025-07-26        Davey Grant     Da'Mon Blackshear          0.0
# 4       9 2025-07-26      Billy Elekana             Ibo Aslan          0.0
# 2      11 2025-07-26       Martin Buday       Marcus Buchecha          0.0
# 1       1 2025-07-26      Marcus McGhee              Petr Yan          0.0
# 10      3 2025-07-26      Asu Almabayev            Jose Ochoa          0.0
# 5       8 2025-07-26      Tabatha Ricci          Amanda Ribas          0.0
# 11      2 2025-07-26    Shara Magomedov  Marc-Andre Barriault          0.0
# 3      10 2025-07-26      Steven Nguyen        Mohammad Yahya          0.0
# 13      0 2025-07-26  Reinier de Ridder      Robert Whittaker          1.0
# 20      5 2025-07-26  Said Nurmagomedov        Bryce Mitchell          0.0
#
#     STR_Absorbed  SUB_Faced  Is_Winner Last_Fight_Date Days_Since_Last_Fight  \
# 0           67.0        0.0      False      2024-10-26              273 days
# 18          34.0        0.0      False      2025-01-11              196 days
# 9           16.0        0.0       True      2025-01-18              189 days
# 8           20.0        1.0       True      2025-04-12              105 days
# 7            5.0        0.0       True      2024-11-23              245 days
# 6           33.0        1.0       True      2024-12-14              224 days
# 4           28.0        0.0       True      2025-01-18              189 days
# 2           24.0        0.0       True      2025-04-05              112 days
# 1           81.0        0.0      False      2024-11-16              252 days
# 10          26.0        2.0       True      2025-03-01              147 days
# 5           30.0        0.0       True      2024-11-23              245 days
# 11          39.0        0.0       True      2025-02-01              175 days
# 3           57.0        0.0       True      2024-03-23              490 days
# 13          66.0        0.0       True      2025-05-03               84 days
# 20          13.0        0.0      False      2025-02-01              175 days
#
#     ...  Prev_SUB_Faced  Past_3_KD_Absorbed  Past_3_STR_Absorbed  \
# 0   ...             1.0            0.000000            25.000000
# 18  ...             1.0            0.000000            58.333333
# 9   ...             0.0            0.000000            17.333333
# 8   ...             3.0            0.666667            11.666667
# 7   ...             0.0            0.333333            21.000000
# 6   ...             0.0            0.000000            53.000000
# 4   ...             2.0                 NaN                  NaN
# 2   ...             0.0            0.000000            53.000000
# 1   ...             0.0            0.000000            26.666667
# 10  ...             0.0            0.000000            27.333333
# 5   ...             0.0            0.000000            90.000000
# 11  ...             0.0            0.000000            65.666667
# 3   ...             0.0                 NaN                  NaN
# 13  ...             0.0            0.000000            16.333333
# 20  ...             1.0            0.000000            27.333333
#
#     Past_3_SUB_Faced  UFC_Debut  Won_Last_Fight  Prev_3_Fight_Win_Rate  \
# 0           0.333333      False           False               0.666667
# 18          0.333333      False           False               0.333333
# 9           0.333333      False            True               1.000000
# 8           1.333333      False           False               0.333333
# 7           0.000000      False            True               0.666667
# 6           0.000000      False            True               0.666667
# 4                NaN      False           False                    NaN
# 2           0.000000      False            True               0.666667
# 1           0.000000      False            True               1.000000
# 10          0.666667      False           False               0.666667
# 5           0.000000      False           False               0.666667
# 11          0.000000      False           False               0.666667
# 3                NaN      False           False                    NaN
# 13          0.000000      False            True               1.000000
# 20          0.666667      False           False               0.333333
#
#     Wins_Before_Fight  Lost_Last_Fight  Losses_Before_Fight
# 0                  17             True                    6
# 18                  7             True                    5
# 9                   3            False                    1
# 8                   8             True                    3
# 7                   8            False                    4
# 6                   7            False                    6
# 4                   0             True                    1
# 2                   6            False                    1
# 1                   4            False                    0
# 10                  4             True                    1
# 5                   6             True                    3
# 11                  4             True                    1
# 3                   0             True                    1
# 13                  3            False                    0
# 20                  7             True                    3
#
# [15 rows x 22 columns]

# %%
test4.to_csv("test4.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
median_layoff
# Out:
# np.float64(168.0)

# %%
# days = test2["Days_Since_Last_Fight"].dropna().astype("int")
# average_layoff = np.mean(days)
# median_layoff = np.median(days)

# %%
# median_layoff_fill = np.median(test2["Days_Since_Last_Fight"].dropna())

# %%
# test2["Days_Since_Last_Fight"].dt.days.hist(bins=50)
# plt.axvline(x=average_layoff, color="red")
# plt.axvline(x=median_layoff, color="purple")

# %%
test2["Days_Since_Last_Fight"].fillna("168 Days", inplace=True)
# Out:
# C:\Users\alexz\AppData\Local\Temp\ipykernel_26084\3869825425.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test2["Days_Since_Last_Fight"].fillna("168 Days", inplace=True)

# %%
test2.isna().sum()
# Out:
# Unnamed: 0                  0
# index                       0
# Date                        0
# Fighter                     0
# Opponent                    0
# KD_Absorbed                 0
# STR_Absorbed                0
# SUB_Faced                   0
# Is_Winner                   0
# Prev_KD_Absorbed            0
# Prev_STR_Absorbed           0
# Prev_SUB_Faced              0
# Past_3_KD_Absorbed          0
# Past_3_STR_Absorbed         0
# Past_3_SUB_Faced            0
# Last_Fight_Date          1483
# Days_Since_Last_Fight       0
# dtype: int64

# %%
date_pattern =r"[0-9]+"
test2["Days_Since_Last_Fight"].str.findall(date_pattern)
# Out:
# 0       [273]
# 1       [252]
# 2       [112]
# 3       [245]
# 4       [224]
#         ...
# 9946      [0]
# 9947     [98]
# 9948    [182]
# 9949    [168]
# 9950    [168]
# Name: Days_Since_Last_Fight, Length: 9951, dtype: object

# %%
test2["Days_Since_Last_Fight"] = test2["Days_Since_Last_Fight"].str.findall(date_pattern).str[0]

# %%
test2 #For fighters who were removed from the dataset because they didn't have a "past 3 fights" to get stats from, and thus there previous fight date w
# Out:
#       Unnamed: 0  index        Date           Fighter           Opponent  \
# 0              0      0  2025-07-26  Robert Whittaker  Reinier de Ridder
# 1              1      1  2025-07-26     Marcus McGhee           Petr Yan
# 2              2     11  2025-07-26      Martin Buday    Marcus Buchecha
# 3              5      8  2025-07-26     Tabatha Ricci       Amanda Ribas
# 4              6      7  2025-07-26       Davey Grant  Da'Mon Blackshear
# ...          ...    ...         ...               ...                ...
# 9946       13899   8247  1994-12-16      Royce Gracie      Keith Hackney
# 9947       13901   8251  1994-12-16      Royce Gracie      Ron van Clief
# 9948       13904   8257  1994-09-09      Royce Gracie      Kimo Leopoldo
# 9949       13908   8268  1994-03-11      Royce Gracie    Minoki Ichihara
# 9950       13909   8267  1994-03-11     Patrick Smith       Scott Morris
#
#       KD_Absorbed  STR_Absorbed  SUB_Faced  Is_Winner  Prev_KD_Absorbed  \
# 0             0.0          67.0        0.0      False               0.0
# 1             0.0          81.0        0.0      False               0.0
# 2             0.0          24.0        0.0       True               0.0
# 3             0.0          30.0        0.0       True               0.0
# 4             0.0          33.0        1.0       True               0.0
# ...           ...           ...        ...        ...               ...
# 9946          0.0           4.0        0.0       True               0.0
# 9947          0.0           0.0        0.0       True               0.0
# 9948          0.0           6.0        0.0       True               0.0
# 9949          0.0           3.0        0.0       True               0.0
# 9950          0.0           0.0        0.0       True               0.0
#
#       Prev_STR_Absorbed  Prev_SUB_Faced  Past_3_KD_Absorbed  \
# 0                   3.0             1.0                 0.0
# 1                  48.0             0.0                 0.0
# 2                  36.0             0.0                 0.0
# 3                  78.0             0.0                 0.0
# 4                  69.0             0.0                 0.0
# ...                 ...             ...                 ...
# 9946                0.0             0.0                 0.0
# 9947                6.0             0.0                 0.0
# 9948                3.0             0.0                 0.0
# 9949                0.0             0.0                 0.0
# 9950                4.0             0.0                 0.0
#
#       Past_3_STR_Absorbed  Past_3_SUB_Faced Last_Fight_Date  \
# 0               25.000000          0.333333      2024-10-26
# 1               26.666667          0.000000      2024-11-16
# 2               53.000000          0.000000      2025-04-05
# 3               90.000000          0.000000      2024-11-23
# 4               53.000000          0.000000      2024-12-14
# ...                   ...               ...             ...
# 9946             3.000000          0.000000      1994-12-16
# 9947             3.000000          0.000000      1994-09-09
# 9948             1.000000          0.000000      1994-03-11
# 9949             0.333333          0.000000            None
# 9950             3.000000          0.000000            None
#
#      Days_Since_Last_Fight
# 0                      273
# 1                      252
# 2                      112
# 3                      245
# 4                      224
# ...                    ...
# 9946                     0
# 9947                    98
# 9948                   182
# 9949                   168
# 9950                   168
#
# [9951 rows x 17 columns]

# %%
df
# Out:
#       Unnamed: 0       Date       Weight class Method  Round Winner  \
# 0              0 2025-07-26       Middleweight    DEC      5   Blue
# 1              1 2025-07-26       Bantamweight    DEC      3   Blue
# 2              2 2025-07-26       Middleweight    DEC      3   Blue
# 3              3 2025-07-26          Flyweight    DEC      3   Blue
# 4              4 2025-07-26  Light Heavyweight     KO      1   Blue
# ...          ...        ...                ...    ...    ...    ...
# 8271        8271 1994-03-11        Open Weight     KO      1   Blue
# 8272        8272 1994-03-11        Open Weight    SUB      1   Blue
# 8273        8273 1994-03-11        Open Weight     KO      1   Blue
# 8274        8274 1994-03-11        Open Weight    SUB      1   Blue
# 8275        8275 1994-03-11        Open Weight    SUB      1   Blue
#
#                    Blue                   Red  Blue_Kd_Landed  Red_Kd_Landed  \
# 0     Reinier de Ridder      Robert Whittaker             0.0            1.0
# 1              Petr Yan         Marcus McGhee             0.0            0.0
# 2       Shara Magomedov  Marc-Andre Barriault             0.0            0.0
# 3         Asu Almabayev            Jose Ochoa             0.0            0.0
# 4         Bogdan Guskov         Nikita Krylov             1.0            0.0
# ...                 ...                   ...             ...            ...
# 8271       Orlando Wiet      Robert Lucarelli             0.0            0.0
# 8272      Frank Hamaker       Thaddeus Luster             0.0            0.0
# 8273      Johnny Rhodes         David Levicki             0.0            0.0
# 8274      Patrick Smith            Ray Wizard             0.0            0.0
# 8275       Scott Morris        Sean Daugherty             0.0            0.0
#
#       Blue_Str_Landed  Red_Str_Landed  Blue_Sub_Landed  Red_Sub_Landed
# 0                67.0            66.0              0.0             0.0
# 1                81.0            64.0              0.0             0.0
# 2                93.0            39.0              0.0             0.0
# 3                22.0            26.0              2.0             2.0
# 4                23.0            16.0              0.0             0.0
# ...               ...             ...              ...             ...
# 8271              8.0             2.0              0.0             1.0
# 8272              2.0             0.0              3.0             0.0
# 8273             11.0             4.0              0.0             0.0
# 8274              1.0             1.0              1.0             0.0
# 8275              1.0             0.0              1.0             0.0
#
# [8276 rows x 14 columns]

# %%
missing_info = df[["Weight class", "Method", "Round", "Blue", "Red", "Date"]]
missing_info2 = missing_info.copy()

# %%
missing_info2[["Red", "Blue"]] = missing_info2[["Blue", "Red"]]

# %%
missing_infofinal = pd.concat([missing_info, missing_info2])

# %%
missing_infofinal
# Out:
#            Weight class Method  Round               Blue  \
# 0          Middleweight    DEC      5  Reinier de Ridder
# 1          Bantamweight    DEC      3           Petr Yan
# 2          Middleweight    DEC      3    Shara Magomedov
# 3             Flyweight    DEC      3      Asu Almabayev
# 4     Light Heavyweight     KO      1      Bogdan Guskov
# ...                 ...    ...    ...                ...
# 8271        Open Weight     KO      1   Robert Lucarelli
# 8272        Open Weight    SUB      1    Thaddeus Luster
# 8273        Open Weight     KO      1      David Levicki
# 8274        Open Weight    SUB      1         Ray Wizard
# 8275        Open Weight    SUB      1     Sean Daugherty
#
#                        Red       Date
# 0         Robert Whittaker 2025-07-26
# 1            Marcus McGhee 2025-07-26
# 2     Marc-Andre Barriault 2025-07-26
# 3               Jose Ochoa 2025-07-26
# 4            Nikita Krylov 2025-07-26
# ...                    ...        ...
# 8271          Orlando Wiet 1994-03-11
# 8272         Frank Hamaker 1994-03-11
# 8273         Johnny Rhodes 1994-03-11
# 8274         Patrick Smith 1994-03-11
# 8275          Scott Morris 1994-03-11
#
# [16552 rows x 6 columns]

# %%
missing_infofinal.to_csv("missing_info.csv")
